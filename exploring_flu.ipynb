# %%
import pandas as pd

# %%
df = pd.read_csv("FluViewPhase2Data/ILINet.csv")
df.reset_index(inplace=True)
df
# Out:
#            level_0        level_1 level_2 level_3         level_4  \
# 0      REGION TYPE         REGION    YEAR    WEEK  % WEIGHTED ILI
# 1           States        Alabama    2010      40               X
# 2           States         Alaska    2010      40               X
# 3           States        Arizona    2010      40               X
# 4           States       Arkansas    2010      40               X
# ...            ...            ...     ...     ...             ...
# 36446       States       Virginia    2024      38               X
# 36447       States     Washington    2024      38               X
# 36448       States  West Virginia    2024      38               X
# 36449       States      Wisconsin    2024      38               X
# 36450       States        Wyoming    2024      38               X
#
#                level_5  level_6    level_7    level_8   level_9   level_10  \
# 0      %UNWEIGHTED ILI  AGE 0-4  AGE 25-49  AGE 25-64  AGE 5-24  AGE 50-64
# 1              2.13477        X          X          X         X          X
# 2             0.875146        X          X          X         X          X
# 3             0.674721        X          X          X         X          X
# 4             0.696056        X          X          X         X          X
# ...                ...      ...        ...        ...       ...        ...
# 36446          2.33884        X          X          X         X          X
# 36447          0.77364        X          X          X         X          X
# 36448          1.57379        X          X          X         X          X
# 36449          1.36431        X          X          X         X          X
# 36450            2.058        X          X          X         X          X
#
#       level_11  level_12           level_13  \
# 0       AGE 65  ILITOTAL  NUM. OF PROVIDERS
# 1            X       249                 35
# 2            X        15                  7
# 3            X       172                 49
# 4            X        18                 15
# ...        ...       ...                ...
# 36446        X      2753                198
# 36447        X       552                108
# 36448        X       183                 39
# 36449        X       414                 61
# 36450        X        22                  7
#
#       PERCENTAGE OF VISITS FOR INFLUENZA-LIKE-ILLNESS REPORTED BY SENTINEL PROVIDERS
# 0                                         TOTAL PATIENTS
# 1                                                  11664
# 2                                                   1714
# 3                                                  25492
# 4                                                   2586
# ...                                                  ...
# 36446                                             117708
# 36447                                              71351
# 36448                                              11628
# 36449                                              30345
# 36450                                               1069
#
# [36451 rows x 15 columns]

# %%
df.columns = df.iloc[0]
df = df.drop(0)
df['WEEK'] = df['WEEK'].astype(int)
df.head()
# Out:
# 0 REGION TYPE      REGION  YEAR  WEEK % WEIGHTED ILI %UNWEIGHTED ILI AGE 0-4  \
# 1      States     Alabama  2010    40              X         2.13477       X
# 2      States      Alaska  2010    40              X        0.875146       X
# 3      States     Arizona  2010    40              X        0.674721       X
# 4      States    Arkansas  2010    40              X        0.696056       X
# 5      States  California  2010    40              X         1.95412       X
#
# 0 AGE 25-49 AGE 25-64 AGE 5-24 AGE 50-64 AGE 65 ILITOTAL NUM. OF PROVIDERS  \
# 1         X         X        X         X      X      249                35
# 2         X         X        X         X      X       15                 7
# 3         X         X        X         X      X      172                49
# 4         X         X        X         X      X       18                15
# 5         X         X        X         X      X      632               112
#
# 0 TOTAL PATIENTS
# 1          11664
# 2           1714
# 3          25492
# 4           2586
# 5          32342

# %%
def week_to_quarter(week):
    if week <= 13:
        return '1'
    elif week <= 26:
        return '2'
    elif week <= 39:
        return '3'
    else:
        return '4'

# Apply the function to create a new column 'QUARTER'
df['QUARTER'] = df['WEEK'].apply(week_to_quarter)
df
# Out:
# 0     REGION TYPE         REGION  YEAR  WEEK % WEIGHTED ILI %UNWEIGHTED ILI  \
# 1          States        Alabama  2010    40              X         2.13477
# 2          States         Alaska  2010    40              X        0.875146
# 3          States        Arizona  2010    40              X        0.674721
# 4          States       Arkansas  2010    40              X        0.696056
# 5          States     California  2010    40              X         1.95412
# ...           ...            ...   ...   ...            ...             ...
# 36446      States       Virginia  2024    38              X         2.33884
# 36447      States     Washington  2024    38              X         0.77364
# 36448      States  West Virginia  2024    38              X         1.57379
# 36449      States      Wisconsin  2024    38              X         1.36431
# 36450      States        Wyoming  2024    38              X           2.058
#
# 0     AGE 0-4 AGE 25-49 AGE 25-64 AGE 5-24 AGE 50-64 AGE 65 ILITOTAL  \
# 1           X         X         X        X         X      X      249
# 2           X         X         X        X         X      X       15
# 3           X         X         X        X         X      X      172
# 4           X         X         X        X         X      X       18
# 5           X         X         X        X         X      X      632
# ...       ...       ...       ...      ...       ...    ...      ...
# 36446       X         X         X        X         X      X     2753
# 36447       X         X         X        X         X      X      552
# 36448       X         X         X        X         X      X      183
# 36449       X         X         X        X         X      X      414
# 36450       X         X         X        X         X      X       22
#
# 0     NUM. OF PROVIDERS TOTAL PATIENTS QUARTER
# 1                    35          11664       4
# 2                     7           1714       4
# 3                    49          25492       4
# 4                    15           2586       4
# 5                   112          32342       4
# ...                 ...            ...     ...
# 36446               198         117708       3
# 36447               108          71351       3
# 36448                39          11628       3
# 36449                61          30345       3
# 36450                 7           1069       3
#
# [36450 rows x 16 columns]

# %%
flu_df = df.drop(columns=['REGION TYPE', 'WEEK', '% WEIGHTED ILI', '%UNWEIGHTED ILI', 'AGE 0-4',	'AGE 25-49',	'AGE 25-64',	'AGE 5-24',	'AGE 50-64',	'AGE 65'])
flu_df['ILITOTAL'] = flu_df['ILITOTAL'].astype(int)
flu_df
# Out:
# 0             REGION  YEAR  ILITOTAL NUM. OF PROVIDERS TOTAL PATIENTS QUARTER
# 1            Alabama  2010       249                35          11664       4
# 2             Alaska  2010        15                 7           1714       4
# 3            Arizona  2010       172                49          25492       4
# 4           Arkansas  2010        18                15           2586       4
# 5         California  2010       632               112          32342       4
# ...              ...   ...       ...               ...            ...     ...
# 36446       Virginia  2024      2753               198         117708       3
# 36447     Washington  2024       552               108          71351       3
# 36448  West Virginia  2024       183                39          11628       3
# 36449      Wisconsin  2024       414                61          30345       3
# 36450        Wyoming  2024        22                 7           1069       3
#
# [36450 rows x 6 columns]

# %%
flu_grouped = flu_df.groupby(['REGION', 'YEAR', 'QUARTER']).agg({
    'ILITOTAL': 'sum',
}).reset_index()
flu_grouped
# Out:
# 0      REGION  YEAR QUARTER  ILITOTAL
# 0     Alabama  2010       4      7488
# 1     Alabama  2011       1     14033
# 2     Alabama  2011       2      2183
# 3     Alabama  2011       3      1758
# 4     Alabama  2011       4      4607
# ...       ...   ...     ...       ...
# 2795  Wyoming  2023       3       476
# 2796  Wyoming  2023       4      2223
# 2797  Wyoming  2024       1      3159
# 2798  Wyoming  2024       2       814
# 2799  Wyoming  2024       3       187
#
# [2800 rows x 4 columns]

# %%
all_states = [
    "Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware", "Florida",
    "Georgia", "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana", "Maine",
    "Maryland", "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", "Nebraska",
    "Nevada", "New Hampshire", "New Jersey", "New Mexico", "New York", "North Carolina", "North Dakota",
    "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", "South Dakota", "Tennessee",
    "Texas", "Utah", "Vermont", "Virginia", "Washington", "West Virginia", "Wisconsin", "Wyoming"
]

# %%
pop_df = pd.read_csv("data/state_population.csv")
pop_df.head()
# Out:
#    SUMLEV REGION DIVISION  STATE              NAME  CENSUS2010POP  \
# 0      10      0        0      0     United States      308745538
# 1      20      1        0      0  Northeast Region       55317240
# 2      20      2        0      0    Midwest Region       66927001
# 3      20      3        0      0      South Region      114555744
# 4      20      4        0      0       West Region       71945553
#
#    ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 0          308758105        309327143        311583481        313877662
# 1           55318414         55380764         55608318         55782661
# 2           66929737         66975328         67164092         67348275
# 3          114563042        114869421        116019483        117264196
# 4           71946912         72101630         72791588         73482530
#
#    POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  POPESTIMATE2016  \
# 0        316059947        318386329        320738994        323071755
# 1         55912775         56021339         56052790         56063777
# 2         67576524         67765576         67885682         68018175
# 3        118397213        119666248        121049223        122419547
# 4         74173435         74933166         75751299         76570256
#
#    POPESTIMATE2017  POPESTIMATE2018  POPESTIMATE2019  POPESTIMATE042020  \
# 0        325122128        326838199        328329953          329398742
# 1         56083383         56084543         56002934           55924275
# 2         68160342         68263019         68340091           68357895
# 3        123611036        124649156        125686544          126494232
# 4         77267367         77841481         78300384           78622340
#
#    POPESTIMATE2020
# 0        329484123
# 1         55849869
# 2         68316744
# 3        126662754
# 4         78654756

# %%
pop_df = pop_df.loc[pop_df['NAME'].isin(all_states)]
pop_df = pop_df.drop(columns=['POPESTIMATE042020', 'ESTIMATESBASE2010', 'CENSUS2010POP', 'DIVISION', 'REGION', 'SUMLEV'])
pop_df
# Out:
#     STATE            NAME  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 5       1         Alabama          4785514          4799642          4816632
# 6       2          Alaska           713982           722349           730810
# 7       4         Arizona          6407342          6473416          6556344
# 8       5        Arkansas          2921998          2941038          2952876
# 9       6      California         37319550         37636311         37944551
# 10      8        Colorado          5047539          5121900          5193660
# 11      9     Connecticut          3579173          3588632          3595211
# 12     10        Delaware           899647           907590           915518
# 14     12         Florida         18846143         19055607         19302016
# 15     13         Georgia          9712209          9803630          9903580
# 16     15          Hawaii          1364004          1379562          1395199
# 17     16           Idaho          1570819          1584272          1595910
# 18     17        Illinois         12840545         12867783         12883029
# 19     18         Indiana          6490555          6517250          6538989
# 20     19            Iowa          3050819          3066772          3076844
# 21     20          Kansas          2858266          2869677          2886024
# 22     21        Kentucky          4348464          4370817          4387865
# 23     22       Louisiana          4544635          4576244          4602067
# 24     23           Maine          1327651          1328473          1328094
# 25     24        Maryland          5788784          5840241          5888375
# 26     25   Massachusetts          6566440          6614218          6664269
# 27     26        Michigan          9877597          9883053          9898289
# 28     27       Minnesota          5310934          5346620          5377500
# 29     28     Mississippi          2970615          2979147          2984599
# 30     29        Missouri          5996089          6011182          6026027
# 31     30         Montana           990730           997518          1004168
# 32     31        Nebraska          1829591          1840914          1853691
# 33     32          Nevada          2702483          2713114          2744670
# 34     33   New Hampshire          1316807          1320444          1324677
# 35     34      New Jersey          8799451          8828552          8845671
# 36     35      New Mexico          2064614          2080707          2087715
# 37     36        New York         19399956         19499921         19574362
# 38     37  North Carolina          9574586          9658913          9751810
# 39     38    North Dakota           674752           685526           702227
# 40     39            Ohio         11539449         11545735         11550971
# 41     40        Oklahoma          3760014          3788824          3819320
# 42     41          Oregon          3837614          3872672          3900102
# 43     42    Pennsylvania         12711406         12747052         12769123
# 44     44    Rhode Island          1053994          1053829          1054893
# 45     45  South Carolina          4635846          4672655          4719027
# 46     46    South Dakota           816193           823740           833859
# 47     47       Tennessee          6355518          6400298          6455752
# 48     48           Texas         25241897         25645504         26084120
# 49     49            Utah          2775413          2814797          2854146
# 50     50         Vermont           625886           627197           626361
# 51     51        Virginia          8024004          8102437          8187456
# 52     53      Washington          6743009          6827479          6898599
# 53     54   West Virginia          1854265          1856606          1857446
# 54     55       Wisconsin          5690538          5705840          5720825
# 55     56         Wyoming           564531           567491           576656
#
#     POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  POPESTIMATE2016  \
# 5           4831586          4843737          4854803          4866824
# 6            737626           737075           738430           742575
# 7           6634690          6732873          6832810          6944767
# 8           2960459          2968759          2979732          2991815
# 9          38253768         38586706         38904296         39149186
# 10          5270774          5352637          5454328          5543844
# 11          3595792          3595697          3588561          3579830
# 12           924062           933131           942065           949989
# 14         19551678         19853880         20219111         20627237
# 15          9975592         10071204         10183353         10308442
# 16          1408822          1415335          1422999          1428885
# 17          1612053          1632248          1652495          1684036
# 18         12895778         12885092         12859585         12821709
# 19          6570575          6596019          6611442          6637898
# 20          3093935          3110643          3122541          3133210
# 21          2894306          2901861          2910717          2912977
# 22          4406906          4416992          4429126          4440306
# 23          4626040          4645938          4666998          4681346
# 24          1328543          1331217          1329098          1332348
# 25          5925197          5960064          5988528          6007014
# 26          6715158          6764864          6797484          6827280
# 27          9914802          9932033          9934483          9954117
# 28          5414722          5452665          5484002          5525360
# 29          2989839          2991892          2990231          2990595
# 30          6042989          6059130          6075411          6091384
# 31          1014158          1022657          1031495          1042137
# 32          1865813          1879955          1892059          1906483
# 33          2776956          2818935          2868531          2919555
# 34          1327272          1334257          1337480          1343694
# 35          8857821          8867277          8870312          8873584
# 36          2092833          2090236          2090071          2092555
# 37         19626488         19653431         19657321         19636391
# 38          9846717          9937295         10037218         10161802
# 39           723149           738736           755537           756114
# 40         11579692         11606573         11622315         11640060
# 41          3853891          3879187          3910518          3928143
# 42          3924110          3965447          4018542          4093271
# 43         12779538         12792392         12789838         12788468
# 44          1055560          1056511          1056886          1057816
# 45          4766469          4826858          4896006          4963031
# 46           842751           849670           854663           863693
# 47          6496943          6544617          6595354          6651277
# 48         26479646         26963092         27468531         27914064
# 49          2898773          2938327          2983626          3044241
# 50           626603           625693           625810           624366
# 51          8255861          8315430          8367303          8417651
# 52          6966252          7057531          7167287          7299961
# 53          1854768          1850569          1843332          1832435
# 54          5738012          5753199          5762927          5775170
# 55           582620           583159           586389           585243
#
#     POPESTIMATE2017  POPESTIMATE2018  POPESTIMATE2019  POPESTIMATE2020
# 5           4877989          4891628          4907965          4921532
# 6            740983           736624           733603           731158
# 7           7048088          7164228          7291843          7421401
# 8           3003855          3012161          3020985          3030522
# 9          39337785         39437463         39437610         39368078
# 10          5617421          5697155          5758486          5807719
# 11          3575324          3574561          3566022          3557006
# 12           957942           966985           976668           986809
# 14         20977089         21254926         21492056         21733312
# 15         10417031         10519389         10628020         10710017
# 16          1425763          1423102          1415615          1407006
# 17          1719745          1752074          1789060          1826913
# 18         12779893         12724685         12667017         12587530
# 19          6662068          6698481          6731010          6754953
# 20          3143734          3149900          3159596          3163561
# 21          2910892          2912748          2912635          2913805
# 22          4455590          4464273          4472345          4477251
# 23          4673673          4664450          4658285          4645318
# 24          1335743          1340123          1345770          1350141
# 25          6028186          6042153          6054954          6055802
# 26          6863560          6885720          6894883          6893574
# 27          9976752          9987286          9984795          9966555
# 28          5569283          5608762          5640053          5657342
# 29          2990674          2982879          2978227          2966786
# 30          6111382          6125986          6140475          6151548
# 31          1053862          1061818          1070123          1080577
# 32          1916998          1925512          1932571          1937552
# 33          2972097          3030725          3090771          3138259
# 34          1350395          1355064          1360783          1366275
# 35          8888147          8891730          8891258          8882371
# 36          2092844          2093754          2099634          2106319
# 37         19593849         19544098         19463131         19336776
# 38         10275758         10391358         10501384         10600823
# 39           756755           760062           763724           765309
# 40         11665706         11680892         11696507         11693217
# 41          3933602          3943488          3960676          3980783
# 42          4147294          4183538          4216116          4241507
# 43         12794679         12809107         12798883         12783254
# 44          1056554          1059338          1058158          1057125
# 45          5027102          5091702          5157702          5218040
# 46           873732           879386           887127           892717
# 47          6714748          6778180          6830325          6886834
# 48         28291024         28624564         28986794         29360759
# 49          3103540          3155153          3203383          3249879
# 50           625132           624802           624046           623347
# 51          8471011          8510920          8556642          8590563
# 52          7427951          7526793          7614024          7693612
# 53          1818683          1805953          1795263          1784787
# 54          5793147          5809319          5824581          5832655
# 55           579994           579054           580116           582328

# %%
df_melted = pd.melt(pop_df,
                    id_vars=['NAME'],  # Columns that should remain as is (like 'STATE')
                    value_vars=['POPESTIMATE2010', 'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013',
                                'POPESTIMATE2014', 'POPESTIMATE2015', 'POPESTIMATE2016', 'POPESTIMATE2017',
                                'POPESTIMATE2018', 'POPESTIMATE2019', 'POPESTIMATE2020'],  # Columns to unpivot
                    var_name='Year',  # New column for years
                    value_name='Population')  # New column for population estimates

df_melted['Year'] = df_melted['Year'].str.extract('(\d+)')


df_melted.head()
# Out:
#          NAME  Year  Population
# 0     Alabama  2010     4785514
# 1      Alaska  2010      713982
# 2     Arizona  2010     6407342
# 3    Arkansas  2010     2921998
# 4  California  2010    37319550

# %%
merged_df = pd.merge(df_melted, flu_grouped,
                     left_on=['NAME', 'Year'],  # Use 'State_Name' and 'Year' from df1
                     right_on=['REGION', 'YEAR'],  # Use 'STATE' and 'Year_Recorded' from df2
                     how='inner')  # You can choose 'left', 'right', 'outer', or 'inner'
merged_df
# Out:
#             NAME  Year  Population      REGION  YEAR QUARTER  ILITOTAL
# 0        Alabama  2010     4785514     Alabama  2010       4      7488
# 1         Alaska  2010      713982      Alaska  2010       4       202
# 2        Arizona  2010     6407342     Arizona  2010       4      4088
# 3       Arkansas  2010     2921998    Arkansas  2010       4       640
# 4     California  2010    37319550  California  2010       4     11502
# ...          ...   ...         ...         ...   ...     ...       ...
# 2045   Wisconsin  2020     5832655   Wisconsin  2020       4      2024
# 2046     Wyoming  2020      582328     Wyoming  2020       1      2542
# 2047     Wyoming  2020      582328     Wyoming  2020       2       270
# 2048     Wyoming  2020      582328     Wyoming  2020       3       103
# 2049     Wyoming  2020      582328     Wyoming  2020       4       390
#
# [2050 rows x 7 columns]

# %%
flu_df['YEAR'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 1        2010
# 2        2010
# 3        2010
# 4        2010
# 5        2010
#          ...
# 36446    2024
# 36447    2024
# 36448    2024
# 36449    2024
# 36450    2024
# Name: YEAR, Length: 36450, dtype: object>

# %%
merged_df = merged_df.drop(columns=['REGION', "YEAR"])
merged_df
# Out:
#             NAME  Year  Population QUARTER  ILITOTAL
# 0        Alabama  2010     4785514       4      7488
# 1         Alaska  2010      713982       4       202
# 2        Arizona  2010     6407342       4      4088
# 3       Arkansas  2010     2921998       4       640
# 4     California  2010    37319550       4     11502
# ...          ...   ...         ...     ...       ...
# 2045   Wisconsin  2020     5832655       4      2024
# 2046     Wyoming  2020      582328       1      2542
# 2047     Wyoming  2020      582328       2       270
# 2048     Wyoming  2020      582328       3       103
# 2049     Wyoming  2020      582328       4       390
#
# [2050 rows x 5 columns]

# %%
merged_df['Year'].value_counts()
# Out:
# Year
# 2011    200
# 2012    200
# 2013    200
# 2014    200
# 2015    200
# 2016    200
# 2017    200
# 2018    200
# 2019    200
# 2020    200
# 2010     50
# Name: count, dtype: int64

# %%
weather_df = pd.read_csv("data/state_weather_data.csv")

weather_df.head()
# Out:
#          lat        lon      tz        date     units  cloud_cover.afternoon  \
# 0  33.037792 -86.649186  -06:00  1980-01-16  standard                  48.04
# 1  33.037792 -86.649186  -06:00  1980-01-31  standard                 100.00
# 2  33.037792 -86.649186  -06:00  1980-02-15  standard                  93.51
# 3  33.037792 -86.649186  -06:00  1980-03-01  standard                 100.00
# 4  33.037792 -86.649186  -06:00  1980-03-16  standard                  97.91
#
#    humidity.afternoon  precipitation.total  temperature.min  temperature.max  \
# 0               68.16                10.48           280.66           289.16
# 1               66.01                 6.60           268.88           284.62
# 2               65.63                 9.75           277.85           291.40
# 3               95.13                20.22           268.44           284.49
# 4               60.15                 0.41           285.17           293.68
#
#    temperature.afternoon  temperature.night  temperature.evening  \
# 0                 288.80             281.80               285.91
# 1                 273.01             284.62               271.40
# 2                 289.87             280.20               289.03
# 3                 284.11             281.11               270.19
# 4                 291.91             285.93               291.91
#
#    temperature.morning  pressure.afternoon  wind.max.speed  \
# 0               281.63             1020.82            3.95
# 1               272.82             1025.64            5.83
# 2               278.17             1016.84            4.51
# 3               278.34             1013.76            5.61
# 4               285.58             1022.63            6.52
#
#    wind.max.direction    state
# 0              130.55  Alabama
# 1              349.34  Alabama
# 2              201.23  Alabama
# 3              331.84  Alabama
# 4              163.68  Alabama

# %%
weather_df['month_day'] = weather_df['date'].apply(lambda x: x[5:])
weather_df['Year'] = weather_df['date'].apply(lambda x: x[:4]).astype(int)

weather_df = weather_df.loc[weather_df['Year'] >= 2010]

all_dates = []

for date in weather_df['month_day'].value_counts().keys():
    all_dates.append(date)

# Create a function to map dates to quarters
def assign_quarter(date):
    month = int(date.split('-')[0])  # Extract month
    if month in [1, 2, 3]:
        return '1'
    elif month in [4, 5, 6]:
        return '2'
    elif month in [7, 8, 9]:
        return '3'
    else:
        return '4'

# Apply the function to assign quarters
weather_df['QUARTER'] = weather_df['month_day'].apply(assign_quarter)

weather_df
# Out:
#              lat         lon      tz        date     units  \
# 720    33.037792  -86.649186  -06:00  2010-01-16  standard
# 721    33.037792  -86.649186  -06:00  2010-01-31  standard
# 722    33.037792  -86.649186  -06:00  2010-02-15  standard
# 723    33.037792  -86.649186  -06:00  2010-03-02  standard
# 724    33.037792  -86.649186  -05:00  2010-03-17  standard
# ...          ...         ...     ...         ...       ...
# 55531  42.845280 -107.888595  -06:00  2024-04-30  standard
# 55532  42.845280 -107.888595  -06:00  2024-05-15  standard
# 55533  42.845280 -107.888595  -06:00  2024-05-30  standard
# 55534  42.845280 -107.888595  -06:00  2024-06-14  standard
# 55535  42.845280 -107.888595  -06:00  2024-06-29  standard
#
#        cloud_cover.afternoon  humidity.afternoon  precipitation.total  \
# 720                   100.00               91.78                26.47
# 721                    33.54               64.33                 0.00
# 722                    33.42               56.33                 5.61
# 723                    99.17               96.10                14.27
# 724                   100.00               68.48                 0.40
# ...                      ...                 ...                  ...
# 55531                  21.00               24.00                 0.00
# 55532                  78.00               47.00                 5.45
# 55533                  18.00               19.00                 0.00
# 55534                 100.00               18.00                 1.64
# 55535                   0.00               33.00                 0.00
#
#        temperature.min  temperature.max  ...  temperature.night  \
# 720             281.52           285.84  ...             281.84
# 721             270.84           280.62  ...             271.76
# 722             271.08           280.32  ...             280.32
# 723             276.16           280.19  ...             280.19
# 724             280.90           284.84  ...             281.97
# ...                ...              ...  ...                ...
# 55531           274.77           283.21  ...             280.58
# 55532           278.27           287.95  ...             280.61
# 55533           279.49           290.70  ...             285.12
# 55534           290.62           302.96  ...             290.74
# 55535           280.85           300.46  ...             284.30
#
#        temperature.evening  temperature.morning  pressure.afternoon  \
# 720                 285.60               283.53             1016.60
# 721                 277.27               271.01             1025.06
# 722                 275.71               272.60             1015.49
# 723                 276.66               278.08             1007.61
# 724                 284.29               281.07             1017.04
# ...                    ...                  ...                 ...
# 55531               282.18               275.19             1011.00
# 55532               287.51               278.77             1014.00
# 55533               290.70               279.49             1012.00
# 55534               298.28               291.32             1007.00
# 55535               299.78               281.14             1017.00
#
#        wind.max.speed  wind.max.direction    state month_day  Year  QUARTER
# 720              6.35               88.08  Alabama     01-16  2010        1
# 721              3.76              348.33  Alabama     01-31  2010        1
# 722              5.40              296.51  Alabama     02-15  2010        1
# 723              5.34                1.92  Alabama     03-02  2010        1
# 724              2.46              331.73  Alabama     03-17  2010        1
# ...               ...                 ...      ...       ...   ...      ...
# 55531           11.07              272.00  Wyoming     04-30  2024        2
# 55532            6.00              317.00  Wyoming     05-15  2024        2
# 55533           10.40               76.00  Wyoming     05-30  2024        2
# 55534           16.58              282.00  Wyoming     06-14  2024        2
# 55535            8.62              100.00  Wyoming     06-29  2024        2
#
# [18096 rows x 21 columns]

# %%
weather_df = weather_df.drop(columns=['lat', 'lon', 'tz', 'date', 'units', 'month_day']).reset_index(drop=True)

weather_df = weather_df.astype({
    'QUARTER': 'int',
})

weather_df = weather_df.groupby(['state', 'Year', 'QUARTER']).mean()

weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 2900 entries, ('Alabama', 2010, 1) to ('Wyoming', 2024, 2)
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   cloud_cover.afternoon  2900 non-null   float64
#  1   humidity.afternoon     2900 non-null   float64
#  2   precipitation.total    2900 non-null   float64
#  3   temperature.min        2900 non-null   float64
#  4   temperature.max        2900 non-null   float64
#  5   temperature.afternoon  2900 non-null   float64
#  6   temperature.night      2900 non-null   float64
#  7   temperature.evening    2900 non-null   float64
#  8   temperature.morning    2900 non-null   float64
#  9   pressure.afternoon     2900 non-null   float64
#  10  wind.max.speed         2900 non-null   float64
#  11  wind.max.direction     2900 non-null   float64
# dtypes: float64(12)
# memory usage: 281.1+ KB

# %%
merged_df = merged_df.astype({
    'QUARTER': 'int',
    'Year': 'int',
})

merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2050 entries, 0 to 2049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NAME        2050 non-null   object
#  1   Year        2050 non-null   int64
#  2   Population  2050 non-null   int64
#  3   QUARTER     2050 non-null   int64
#  4   ILITOTAL    2050 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 80.2+ KB

# %%
merged_df.head()
# Out:
#          NAME  Year  Population  QUARTER  ILITOTAL
# 0     Alabama  2010     4785514        4      7488
# 1      Alaska  2010      713982        4       202
# 2     Arizona  2010     6407342        4      4088
# 3    Arkansas  2010     2921998        4       640
# 4  California  2010    37319550        4     11502

# %%
state_land_area = {
    'Alaska': 570641,
    'Texas': 261914,
    'California': 155973,
    'Montana': 145556,
    'New Mexico': 121365,
    'Arizona': 113642,
    'Nevada': 109806,
    'Colorado': 103730,
    'Wyoming': 97105,
    'Oregon': 96003,
    'Idaho': 82751,
    'Utah': 82168,
    'Kansas': 81823,
    'Minnesota': 79617,
    'Nebraska': 76878,
    'South Dakota': 75898,
    'North Dakota': 68994,
    'Missouri': 68898,
    'Oklahoma': 68679,
    'Washington': 66582,
    'Georgia': 57919,
    'Michigan': 56539,
    'Iowa': 55875,
    'Illinois': 55593,
    'Wisconsin': 54314,
    'Florida': 53997,
    'Arkansas': 52075,
    'Alabama': 50750,
    'North Carolina': 48718,
    'New York': 47224,
    'Mississippi': 46914,
    'Pennsylvania': 44820,
    'Louisiana': 43566,
    'Tennessee': 41220,
    'Ohio': 40953,
    'Kentucky': 39732,
    'Virginia': 39598,
    'Indiana': 35870,
    'Maine': 30865,
    'South Carolina': 30111,
    'West Virginia': 24087,
    'Maryland': 9775,
    'Vermont': 9249,
    'New Hampshire': 8969,
    'Massachusetts': 7838,
    'New Jersey': 7419,
    'Hawaii': 6423,
    'Connecticut': 4845,
    'Delaware': 1955,
    'Rhode Island': 1034
}

# %%
def calculate_population_density(row):
    state = row['NAME']  # Adjust the column name if it's different
    population = row['Population']

    # Check if the state exists in the dictionary
    if state in state_land_area:
        # Calculate population density
        return round(population / state_land_area[state])
    else:
        # Return NaN or some default value if the state is not found
        return None

# Apply the function to each row in the DataFrame and create a new column 'Population_Density'
merged_df['Population_Density'] = merged_df.apply(calculate_population_density, axis=1)

# Display the DataFrame
merged_df
# Out:
#             NAME  Year  Population  QUARTER  ILITOTAL  Population_Density
# 0        Alabama  2010     4785514        4      7488                  94
# 1         Alaska  2010      713982        4       202                   1
# 2        Arizona  2010     6407342        4      4088                  56
# 3       Arkansas  2010     2921998        4       640                  56
# 4     California  2010    37319550        4     11502                 239
# ...          ...   ...         ...      ...       ...                 ...
# 2045   Wisconsin  2020     5832655        4      2024                 107
# 2046     Wyoming  2020      582328        1      2542                   6
# 2047     Wyoming  2020      582328        2       270                   6
# 2048     Wyoming  2020      582328        3       103                   6
# 2049     Wyoming  2020      582328        4       390                   6
#
# [2050 rows x 6 columns]

# %%
full_df = pd.merge(merged_df, weather_df,
                     left_on=['NAME', 'Year', 'QUARTER'],
                     right_on=['state', 'Year', 'QUARTER'],
                     how='left')

full_df
# Out:
#             NAME  Year  Population  QUARTER  ILITOTAL  Population_Density  \
# 0        Alabama  2010     4785514        4      7488                  94
# 1         Alaska  2010      713982        4       202                   1
# 2        Arizona  2010     6407342        4      4088                  56
# 3       Arkansas  2010     2921998        4       640                  56
# 4     California  2010    37319550        4     11502                 239
# ...          ...   ...         ...      ...       ...                 ...
# 2045   Wisconsin  2020     5832655        4      2024                 107
# 2046     Wyoming  2020      582328        1      2542                   6
# 2047     Wyoming  2020      582328        2       270                   6
# 2048     Wyoming  2020      582328        3       103                   6
# 2049     Wyoming  2020      582328        4       390                   6
#
#       cloud_cover.afternoon  humidity.afternoon  precipitation.total  \
# 0                 43.596667           45.773333             2.153333
# 1                 41.683333           79.200000             0.588333
# 2                 16.743333           32.430000             0.000000
# 3                  8.358333           44.506667             0.013333
# 4                 34.735833           48.742500             0.935000
# ...                     ...                 ...                  ...
# 2045              64.333333           81.000000             0.300000
# 2046              47.500000           62.666667             0.000000
# 2047              52.333333           41.000000             0.721667
# 2048              15.500000           34.666667             0.190000
# 2049              55.833333           49.333333             0.000000
#
#       temperature.min  temperature.max  temperature.afternoon  \
# 0          277.351667       290.433333             287.283333
# 1          256.830000       262.808333             259.550000
# 2          274.188333       290.601667             287.216667
# 3          278.033333       289.666667             287.205000
# 4          280.821667       292.448333             288.748333
# ...               ...              ...                    ...
# 2045       269.290000       276.068333             273.355000
# 2046       261.110000       274.878333             271.550000
# 2047       280.673333       294.135000             290.245000
# 2048       283.605000       298.418333             294.270000
# 2049       266.928333       277.758333             274.880000
#
#       temperature.night  temperature.evening  temperature.morning  \
# 0            282.620000           283.508333           280.126667
# 1            261.721667           258.753333           259.638333
# 2            278.275000           287.215000           274.833333
# 3            281.496667           285.348333           278.208333
# 4            284.502500           290.601667           281.256667
# ...                 ...                  ...                  ...
# 2045         272.190000           274.368333           272.115000
# 2046         265.741667           271.450000           264.006667
# 2047         285.353333           290.298333           281.743333
# 2048         288.616667           297.946667           284.531667
# 2049         269.603333           273.068333           267.986667
#
#       pressure.afternoon  wind.max.speed  wind.max.direction
# 0            1020.376667        4.173333          291.020000
# 1            1007.650000        3.881667           41.938333
# 2            1020.833333        3.233333          146.158333
# 3            1023.538333        4.621667          260.038333
# 4            1020.871667        3.580000          198.761667
# ...                  ...             ...                 ...
# 2045         1013.500000        6.783333          230.000000
# 2046         1023.333333        8.925000          216.333333
# 2047         1007.333333        9.600000          196.833333
# 2048         1010.833333        7.565000          246.333333
# 2049         1018.833333        8.458333          210.666667
#
# [2050 rows x 18 columns]

# %%
full_df.to_csv("data/flu_weather_df.csv", index=False)
